# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from linearmodels.iv import IV2SLS
import statsmodels.api as sm
import numpy.linalg as npl

# %%
df = pd.read_csv('../output/data/final_dataset.csv')
df.head()
# Out:
#    rank                        app        developer        country  \
# 0   476                   KUNI Cam         GinnyPix         Sweden
# 1   452         Link2SD Plus (New)   Bulent Akpinar          Spain
# 2   291                      Pushy  medienwerkstatt        Germany
# 3   397                    EasyMSR      DEFTUN TECH  United States
# 4   154  GTA: Liberty City Stories   Rockstar Games      Australia
#
#                      app_id  price ndownloads  lowerbound  upperbound  \
# 0         com.ginnypix.kuni   4.49    50,000+       50000      100000
# 1      com.buak.link2sdplus   2.35   100,000+      100000      500000
# 2       de.fk.android.pushy   1.49    10,000+       10000       50000
# 3         com.gbtf.msrx6pro  19.99    10,000+       10000       50000
# 4  com.rockstargames.gtalcs   6.99   100,000+      100000      500000
#
#    averagescore  ...  inapppurchases estimateddownloads     date  newgroup  \
# 0           4.5  ...            True              50000  9/21/19   OUTSIDE
# 1           3.3  ...           False             282840  9/21/19   OUTSIDE
# 2           4.4  ...           False              25040  9/21/19   OUTSIDE
# 3           3.5  ...           False              10000  9/21/19   OUTSIDE
# 4           4.3  ...           False             253380  9/21/19   OUTSIDE
#
#    iap highest_rank lowest_rank  multiplier     new_est     nest
# 0    1           12         498  102.880660   52263.375  OUTSIDE
# 1    0            2         493  814.663940  133401.220  OUTSIDE
# 2    0           11         494   82.815735   26811.594  OUTSIDE
# 3    0            9         500   81.466393   18391.039  OUTSIDE
# 4    0            3         489  823.045290  375720.160  OUTSIDE
#
# [5 rows x 23 columns]

# %% [markdown]
# # Part I Demand Estimation
# ### 1.1 Berry Logit
#
# Compute market share

# %%
# Ok by country because we need US later, but remember to write in pdf

# %%
"""
df['total_market'] = df['new_est'].sum()
df['s_j'] = df['new_est'] / df['total_market']

#compute market share of outside good
df['Q_out'] = df[df['nest'].str.upper() == 'OUTSIDE']['new_est'].sum()
df['s_0'] = df['Q_out'] / df['total_market']
df = df[df['nest'].str.upper() != 'OUTSIDE'].copy() #remove outside good from dataset"""
# Out:
# "\ndf['total_market'] = df['new_est'].sum()\ndf['s_j'] = df['new_est'] / df['total_market']\n\n#compute market share of outside good\ndf['Q_out'] = df[df['nest'].str.upper() == 'OUTSIDE']['new_est'].sum()\ndf['s_0'] = df['Q_out'] / df['total_market']\ndf = df[df['nest'].str.upper() != 'OUTSIDE'].copy() #remove outside good from dataset"

# %%
#total market by country
df['total_market'] = df.groupby('country')['new_est'].transform('sum')
df['s_j'] = df['new_est'] / df['total_market']

#compute market share of outside good
outside_by_country = df[df['nest'].str.upper() == 'OUTSIDE'].groupby('country')['new_est'].sum()
df['Q_out'] = df['country'].map(outside_by_country)
df['s_0'] = df['Q_out'] / df['total_market']
df = df[df['nest'].str.upper() != 'OUTSIDE'].copy() #remove outside good from dataset

# %% [markdown]
# Estimate Berry equation without intruments for prices

# %%
epsilon = 1e-10  # avoid log(0)
df['y'] = np.log(df['s_j'].clip(lower=epsilon)) - np.log(df['s_0'].clip(lower=epsilon))

formula = 'y ~ price + averagescore + iap'

df_clean = df.dropna(subset=['y', 'price', 'averagescore', 'iap', 'country']) #Added df clean cause soemthing was NA

ols = smf.ols(formula=formula, data=df_clean).fit(
    cov_type="cluster", cov_kwds={"groups": df_clean["country"]}
)
print(ols.summary())

fe = smf.ols(formula + " + C(country)", data=df_clean).fit(
    cov_type="cluster", cov_kwds={"groups": df_clean["country"]}
)
print(fe.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     87.67
# Date:                dom, 02 nov 2025   Prob (F-statistic):           5.79e-08
# Time:                        18:49:58   Log-Likelihood:                -9838.1
# No. Observations:                4504   AIC:                         1.968e+04
# Df Residuals:                    4500   BIC:                         1.971e+04
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -7.3341      0.308    -23.827      0.000      -7.937      -6.731
# price            0.0064      0.006      1.155      0.248      -0.004       0.017
# averagescore     0.2332      0.055      4.244      0.000       0.125       0.341
# iap              1.2101      0.080     15.190      0.000       1.054       1.366
# ==============================================================================
# Omnibus:                       79.693   Durbin-Watson:                   1.776
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.454
# Skew:                          -0.330   Prob(JB):                     7.55e-19
# Kurtosis:                       2.902   Cond. No.                         56.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     426.8
# Date:                dom, 02 nov 2025   Prob (F-statistic):           1.16e-11
# Time:                        18:49:58   Log-Likelihood:                -9804.6
# No. Observations:                4504   AIC:                         1.964e+04
# Df Residuals:                    4489   BIC:                         1.974e+04
# Df Model:                          14
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -7.1856      0.259    -27.792      0.000      -7.692      -6.679
# C(country)[T.Canada]             0.2906      0.004     71.532      0.000       0.283       0.299
# C(country)[T.France]            -0.0533      0.004    -12.644      0.000      -0.062      -0.045
# C(country)[T.Germany]           -0.0350      0.002    -18.497      0.000      -0.039      -0.031
# C(country)[T.Italy]             -0.0728      0.004    -18.971      0.000      -0.080      -0.065
# C(country)[T.Japan]              0.5758      0.007     84.794      0.000       0.562       0.589
# C(country)[T.Korea]             -0.1459      0.004    -35.279      0.000      -0.154      -0.138
# C(country)[T.Netherlands]       -0.2282      0.004    -60.933      0.000      -0.236      -0.221
# C(country)[T.Spain]             -0.5293      0.003   -178.426      0.000      -0.535      -0.524
# C(country)[T.Sweden]            -0.2617      0.008    -32.939      0.000      -0.277      -0.246
# C(country)[T.United Kingdom]     0.1214      0.001    118.927      0.000       0.119       0.123
# C(country)[T.United States]      0.1856      0.004     44.516      0.000       0.177       0.194
# price                            0.0023      0.007      0.324      0.746      -0.011       0.016
# averagescore                     0.2081      0.056      3.712      0.000       0.098       0.318
# iap                              1.2058      0.079     15.350      0.000       1.052       1.360
# ==============================================================================
# Omnibus:                       72.304   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.016
# Skew:                          -0.310   Prob(JB):                     5.14e-17
# Kurtosis:                       2.872   Cond. No.                         83.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# c:\Users\guido\OneDrive\Documents\_EIO\empirical-IO-ps\venv\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 3
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# Estimate Berry equation with price instruments

# %%
# One more instrument: number of apps in the same genre (across all countries)

df['Z_numapps'] = (
    df.groupby('appgenre')['app_id'].transform('count').astype(float)
)
df["Z_numapps"] = np.log(df["Z_numapps"].clip(lower=1))

# new: instrument = number of other apps by same developer (exclude the app itself)
df['Z_dev_count'] = df.groupby('developer')['app_id'].transform('count').astype(float)
df['Z_dev_other'] = (df['Z_dev_count'] - 1.0).clip(lower=0.0)   # number of other apps
# log-transform (clip at 1 so single-product devs map to 0)
df['Z_dev_other'] = np.log(df['Z_dev_other'].clip(lower=1.0)) # skewed counts

cols = ["y", "price", "averagescore", "iap", "country", "Z_numapps", "Z_dev_other"]
df = df.replace([np.inf, -np.inf], np.nan).dropna(subset=cols)
df["iap"] = df["iap"].astype(int)
df["country"] = df["country"].astype(str)

fe = pd.get_dummies(df["country"], prefix="cty", drop_first=True)
X = pd.concat([df[["averagescore", "iap"]], fe], axis=1)

# IV with two instruments
iv_res = IV2SLS(
    dependent=df["y"],
    exog=pd.DataFrame({"const": 1}, index=df.index).join(X),
    endog=df[["price"]],
    instruments=df[["Z_numapps", "Z_dev_other"]],
).fit(cov_type="clustered", clusters=df["country"])

print("\n=== IV (2SLS) with country FE, clustered SE by country (two instruments) ===")
print(iv_res.summary)

# First stage (report): include both instruments
fs_mod = smf.ols(
    "price ~ Z_numapps + Z_dev_other + averagescore + iap + C(country)",
    data=df
).fit(cov_type="cluster", cov_kwds={"groups": df["country"]})

print("\n=== First Stage OLS (clustered by country) ===")
print(fs_mod.summary())

# Joint test for instruments (Wald / F)
try:
    w = fs_mod.f_test("Z_numapps = 0, Z_dev_other = 0")
    fval = float(w.fvalue) if hasattr(w, "fvalue") else float(w.statistic)
    pval = float(w.pvalue) if hasattr(w, "pvalue") else np.nan
    print(f"\n[first-stage] joint F (Z_numapps & Z_dev_other) = {fval:.2f}, p = {pval:.3g}")
except Exception:
    pass

# Partial R² of instruments given controls+FE (multivariate analogue)
controls_fe = "averagescore + iap + C(country)"
res_p = smf.ols("price ~ " + controls_fe, data=df).fit().resid
# regress each instrument on controls, then compute R^2 of matrix of residuals projection
res_z1 = smf.ols("Z_numapps ~ " + controls_fe, data=df).fit().resid
res_z2 = smf.ols("Z_dev_other ~ " + controls_fe, data=df).fit().resid
Zres = np.column_stack([res_z1, res_z2])
# compute multivariate partial R2 via projection of res_p on columns of Zres
proj = Zres @ npl.pinv(Zres.T @ Zres) @ Zres.T
SSR_reduced = ((res_p - proj.dot(res_p))**2).sum()
SSR_full = (res_p**2).sum()
partial_R2_multi = 1.0 - SSR_reduced / SSR_full
print(f"[First-stage] multivariate partial R² (instruments | controls+FE): {partial_R2_multi:.4f}")
# Out:
# === IV (2SLS) with country FE, clustered SE by country (two instruments) ===
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:                      y   R-squared:                     -9.0652
# Estimator:                    IV-2SLS   Adj. R-squared:                -9.0965
# No. Observations:                4504   F-statistic:                -4.162e+18
# Date:                dom, nov 02 2025   P-value (F-stat)                1.0000
# Time:                        18:56:59   Distribution:                 chi2(14)
# Cov. Estimator:             clustered
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# const                 -16.702     1.3216    -12.637     0.0000     -19.292     -14.111
# averagescore           0.5455     0.1789     3.0485     0.0023      0.1948      0.8962
# iap                    1.9666     0.2167     9.0747     0.0000      1.5419      2.3914
# cty_Canada            -0.6807     0.1604    -4.2440     0.0000     -0.9951     -0.3664
# cty_France            -1.1607     0.1914    -6.0648     0.0000     -1.5358     -0.7856
# cty_Germany           -0.6105     0.0973    -6.2753     0.0000     -0.8012     -0.4198
# cty_Italy              0.1752     0.0356     4.9185     0.0000      0.1054      0.2450
# cty_Japan             -1.4452     0.3403    -4.2469     0.0000     -2.1121     -0.7782
# cty_Korea             -0.7085     0.0991    -7.1529     0.0000     -0.9027     -0.5144
# cty_Netherlands       -0.2336     0.0087    -26.965     0.0000     -0.2506     -0.2166
# cty_Spain             -0.7158     0.0392    -18.259     0.0000     -0.7927     -0.6390
# cty_Sweden            -1.0272     0.1346    -7.6339     0.0000     -1.2909     -0.7635
# cty_United Kingdom    -0.0922     0.0347    -2.6568     0.0079     -0.1603     -0.0242
# cty_United States     -0.7543     0.1572    -4.7995     0.0000     -1.0623     -0.4463
# price                  2.0805     0.3508     5.9302     0.0000      1.3929      2.7681
# ======================================================================================
#
# Endogenous: price
# Instruments: Z_numapps, Z_dev_other
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 12
#
# === First Stage OLS (clustered by country) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     84.26
# Date:                dom, 02 nov 2025   Prob (F-statistic):           3.55e-08
# Time:                        18:56:59   Log-Likelihood:                -11640.
# No. Observations:                4504   AIC:                         2.331e+04
# Df Residuals:                    4488   BIC:                         2.341e+04
# Df Model:                          15
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.8754      0.428      6.715      0.000       2.036       3.715
# C(country)[T.Canada]             0.4682      0.004    106.979      0.000       0.460       0.477
# C(country)[T.France]             0.5512      0.006     99.875      0.000       0.540       0.562
# C(country)[T.Germany]            0.2932      0.012     25.044      0.000       0.270       0.316
# C(country)[T.Italy]             -0.0870      0.010     -9.088      0.000      -0.106      -0.068
# C(country)[T.Japan]              1.0416      0.018     58.581      0.000       1.007       1.076
# C(country)[T.Korea]              0.3571      0.024     15.136      0.000       0.311       0.403
# C(country)[T.Netherlands]        0.0445      0.013      3.489      0.000       0.020       0.069
# C(country)[T.Spain]              0.1370      0.014     10.052      0.000       0.110       0.164
# C(country)[T.Sweden]             0.4275      0.013     33.037      0.000       0.402       0.453
# C(country)[T.United Kingdom]     0.0922      0.002     38.350      0.000       0.087       0.097
# C(country)[T.United States]      0.4235      0.004    118.934      0.000       0.417       0.431
# Z_numapps                        0.2461      0.053      4.620      0.000       0.142       0.350
# Z_dev_other                      0.2502      0.056      4.477      0.000       0.141       0.360
# averagescore                    -0.2037      0.107     -1.904      0.057      -0.413       0.006
# iap                             -0.4317      0.085     -5.086      0.000      -0.598      -0.265
# ==============================================================================
# Omnibus:                     2940.221   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            45833.789
# Skew:                           2.906   Prob(JB):                         0.00
# Kurtosis:                      17.507   Cond. No.                         105.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# [first-stage] joint F (Z_numapps & Z_dev_other) = 39.19, p = 9.9e-06
# [First-stage] multivariate partial R² (instruments | controls+FE): 0.0125
# c:\Users\guido\OneDrive\Documents\_EIO\empirical-IO-ps\venv\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 15, but rank is 4
#   warnings.warn('covariance of constraints does not have full '

# %%
df['Z_numapps'] = (
    df.groupby(['country','appgenre'])['app_id'].transform('count').astype(float)
)

df["Z_numapps"] = np.log(df["Z_numapps"].clip(lower=1))


cols = ["y", "price", "averagescore", "iap", "country", "Z_numapps"]
df = df.replace([np.inf, -np.inf], np.nan).dropna(subset=cols)
df["iap"] = df["iap"].astype(int)
df["country"] = df["country"].astype(str)

fe = pd.get_dummies(df["country"], prefix="cty", drop_first=True)
X = pd.concat([df[["averagescore", "iap"]], fe], axis=1)

iv_res = IV2SLS(
    dependent=df["y"],
    exog=pd.DataFrame({"const": 1}, index=df.index).join(X),
    endog=df[["price"]],
    instruments=df[["Z_numapps"]],
).fit(cov_type="clustered", clusters=df["country"])

print("\n=== IV (2SLS) with country FE, clustered SE by country ===")
print(iv_res.summary)


# First stage with country FE via C(country)
fs_mod = smf.ols(
    "price ~ Z_numapps + averagescore + iap + C(country)",
    data=df
).fit(cov_type="cluster", cov_kwds={"groups": df["country"]})

print("\n=== First Stage OLS (clustered by country) ===")
print(fs_mod.summary())

# Robust F for excluded instrument (single Z)
t_iv = fs_mod.tvalues["Z_numapps"]
F_iv = float(t_iv**2)
print(f"\n[First-stage] robust t(Z_numapps) = {t_iv:.2f}  →  robust F = {F_iv:.2f}")

# Partial R^2 of instrument given controls + FE
controls_fe = "averagescore + iap + C(country)"
res_p = smf.ols("price ~ " + controls_fe, data=df).fit().resid
res_z = smf.ols("Z_numapps ~ " + controls_fe, data=df).fit().resid
partial_R2 = np.corrcoef(res_p, res_z)[0, 1] ** 2
print(f"[First-stage] partial R² (given controls+FE): {partial_R2:.4f}")
# Out:
# === IV (2SLS) with country FE, clustered SE by country ===
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:                      y   R-squared:                     -0.4128
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.4172
# No. Observations:                4504   F-statistic:                 1.093e+19
# Date:                dom, nov 02 2025   P-value (F-stat)                0.0000
# Time:                        18:58:19   Distribution:                 chi2(14)
# Cov. Estimator:             clustered
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# const                 -4.9876     1.0820    -4.6096     0.0000     -7.1083     -2.8669
# averagescore           0.1302     0.0689     1.8904     0.0587     -0.0048      0.2652
# iap                    1.0300     0.0895     11.508     0.0000      0.8546      1.2055
# cty_Canada             0.5150     0.1218     4.2284     0.0000      0.2763      0.7537
# cty_France             0.2025     0.1411     1.4358     0.1511     -0.0739      0.4790
# cty_Germany            0.0979     0.0733     1.3358     0.1816     -0.0457      0.2415
# cty_Italy             -0.1300     0.0296    -4.3873     0.0000     -0.1881     -0.0719
# cty_Japan              1.0426     0.2592     4.0217     0.0001      0.5345      1.5507
# cty_Korea             -0.0160     0.0746    -0.2138     0.8307     -0.1622      0.1303
# cty_Netherlands       -0.2269     0.0055    -41.395     0.0000     -0.2377     -0.2162
# cty_Spain             -0.4863     0.0257    -18.950     0.0000     -0.5366     -0.4360
# cty_Sweden            -0.0849     0.1038    -0.8177     0.4136     -0.2882      0.1185
# cty_United Kingdom     0.1707     0.0277     6.1598     0.0000      0.1164      0.2250
# cty_United States      0.4027     0.1176     3.4237     0.0006      0.1722      0.6333
# price                 -0.4778     0.2637    -1.8114     0.0701     -0.9947      0.0392
# ======================================================================================
#
# Endogenous: price
# Instruments: Z_numapps
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 12
#
# === First Stage OLS (clustered by country) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     4.351
# Date:                dom, 02 nov 2025   Prob (F-statistic):             0.0299
# Time:                        18:58:19   Log-Likelihood:                -11661.
# No. Observations:                4504   AIC:                         2.335e+04
# Df Residuals:                    4489   BIC:                         2.345e+04
# Df Model:                          14
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.7244      0.345     10.799      0.000       3.048       4.400
# C(country)[T.Canada]             0.4405      0.008     54.680      0.000       0.425       0.456
# C(country)[T.France]             0.5137      0.010     53.196      0.000       0.495       0.533
# C(country)[T.Germany]            0.2582      0.007     36.579      0.000       0.244       0.272
# C(country)[T.Italy]             -0.1374      0.013    -10.736      0.000      -0.163      -0.112
# C(country)[T.Japan]              1.0290      0.020     50.950      0.000       0.989       1.069
# C(country)[T.Korea]              0.2231      0.021     10.667      0.000       0.182       0.264
# C(country)[T.Netherlands]       -0.0135      0.010     -1.374      0.169      -0.033       0.006
# C(country)[T.Spain]              0.0628      0.014      4.420      0.000       0.035       0.091
# C(country)[T.Sweden]             0.3421      0.016     21.052      0.000       0.310       0.374
# C(country)[T.United Kingdom]     0.0847      0.007     12.936      0.000       0.072       0.098
# C(country)[T.United States]      0.4137      0.013     32.213      0.000       0.388       0.439
# Z_numapps                        0.2848      0.105      2.724      0.006       0.080       0.490
# averagescore                    -0.1642      0.105     -1.566      0.117      -0.370       0.041
# iap                             -0.3301      0.088     -3.732      0.000      -0.503      -0.157
# ==============================================================================
# Omnibus:                     2873.896   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41836.573
# Skew:                           2.840   Prob(JB):                         0.00
# Kurtosis:                      16.808   Cond. No.                         70.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# [First-stage] robust t(Z_numapps) = 2.72  →  robust F = 7.42
# [First-stage] partial R² (given controls+FE): 0.0029
# c:\Users\guido\OneDrive\Documents\_EIO\empirical-IO-ps\venv\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 14, but rank is 3
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### 1.2 Nested Logit model

# %%
S_k = df.groupby(['country','nest'])['s_j'].transform('sum')
df['s_j_given_k'] = (df['s_j'] / S_k).clip(lower=1e-12)
df['ln_within'] = np.log(df['s_j_given_k'])


fe = pd.get_dummies(df["country"], prefix="cty", drop_first=True)
X_exog = pd.concat([df[["averagescore","iap","ln_within"]], fe], axis=1)
X_exog = sm.add_constant(X_exog)

Y = df["y"]
P = df[["price"]]        
Z = df[["Z_numapps"]]      

# OLS with formulas and country FE (C(country))
ols = smf.ols("y ~ price + averagescore + iap + ln_within + C(country)", data=df)\
         .fit(cov_type="cluster", cov_kwds={"groups": df["country"]})

# IV: use linearmodels formula interface
iv = IV2SLS.from_formula(
    "y ~ 1 + averagescore + iap + ln_within + C(country) "
    "+ [price ~ Z_numapps]",
    data=df
).fit(cov_type="clustered", clusters=df["country"])

# First stage (for reporting only)
fs = smf.ols("price ~ Z_numapps + averagescore + iap + ln_within + C(country)", data=df)\
        .fit(cov_type="cluster", cov_kwds={"groups": df["country"]})

t_z = fs.tvalues.get("Z_numapps", np.nan)
F_z = float(t_z**2) if np.isfinite(t_z) else np.nan

# Partial R² of Z given controls+FE
res_p = smf.ols("price ~ averagescore + iap + ln_within + C(country)", data=df).fit().resid
res_z = smf.ols("Z_numapps ~ averagescore + iap + ln_within + C(country)", data=df).fit().resid
partial_R2 = float(np.corrcoef(res_p, res_z)[0, 1] ** 2)

print("\n=== Nested Logit: OLS (clustered by country) ===")
print(ols.summary())

print("\n=== Nested Logit: IV-2SLS (price instrumented; clustered by country) ===")
print(iv.summary)

print("\n=== First Stage (price on Z + controls + ln_within + FE) ===")
print(fs.summary())
print(f"\n[First-stage] robust t(Z_numapps) = {t_z:.2f}  →  robust F = {F_z:.2f}")
print(f"[First-stage] partial R² (given controls+FE): {partial_R2:.4f}")

# Comparison table
def pick(res, name):
    params = getattr(res, "params")  # both have .params
    # std errors: statsmodels -> .bse ; linearmodels -> .std_errors
    ses = getattr(res, "bse", None)
    if ses is None:
        ses = getattr(res, "std_errors")  # linearmodels IVResults
    params = pd.Series(params)
    ses = pd.Series(ses)

    # normalize constant name
    const_name = "Intercept" if "Intercept" in params.index else ("const" if "const" in params.index else None)

    keep = ["ln_within", "price", "averagescore", "iap"]
    if const_name:
        keep.append(const_name)

    rows = []
    for k in keep:
        if k in params.index:
            rows.append([k, params[k], ses[k]])
    out = pd.DataFrame(rows, columns=["param", f"{name}_coef", f"{name}_se"])
    return out

tab = pick(ols, "OLS").merge(pick(iv, "IV"), on="param", how="outer")

# pretty order: lambda first, then price, X's, const (Intercept/const label preserved)
order = ["ln_within", "price", "averagescore", "iap", "Intercept", "const"]
tab["order"] = tab["param"].apply(lambda x: order.index(x) if x in order else 99)
tab = tab.sort_values("order").drop(columns="order")

print("\n=== Comparison table (Nested logit: OLS vs IV) ===")
print(tab.to_string(index=False))
# Out:
# === Nested Logit: OLS (clustered by country) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     2413.
# Date:                dom, 02 nov 2025   Prob (F-statistic):           4.19e-16
# Time:                        18:59:38   Log-Likelihood:                -6286.7
# No. Observations:                4504   AIC:                         1.261e+04
# Df Residuals:                    4488   BIC:                         1.271e+04
# Df Model:                          15
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -1.6127      0.113    -14.324      0.000      -1.833      -1.392
# C(country)[T.Canada]             0.2827      0.001    209.088      0.000       0.280       0.285
# C(country)[T.France]             0.0548      0.002     31.168      0.000       0.051       0.058
# C(country)[T.Germany]           -0.0980      0.001    -84.352      0.000      -0.100      -0.096
# C(country)[T.Italy]              0.0409      0.002     22.601      0.000       0.037       0.044
# C(country)[T.Japan]              0.4939      0.004    122.858      0.000       0.486       0.502
# C(country)[T.Korea]              0.3231      0.005     61.306      0.000       0.313       0.333
# C(country)[T.Netherlands]       -0.0703      0.002    -34.334      0.000      -0.074      -0.066
# C(country)[T.Spain]             -0.1555      0.004    -37.521      0.000      -0.164      -0.147
# C(country)[T.Sweden]            -0.1020      0.004    -25.537      0.000      -0.110      -0.094
# C(country)[T.United Kingdom]     0.1774      0.001    181.119      0.000       0.175       0.179
# C(country)[T.United States]      0.2322      0.001    173.569      0.000       0.230       0.235
# price                            0.0029      0.003      1.063      0.288      -0.002       0.008
# averagescore                     0.1492      0.019      7.689      0.000       0.111       0.187
# iap                              0.4531      0.043     10.540      0.000       0.369       0.537
# ln_within                        0.9104      0.010     88.975      0.000       0.890       0.930
# ==============================================================================
# Omnibus:                      167.655   Durbin-Watson:                   0.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.268
# Skew:                          -0.482   Prob(JB):                     3.57e-41
# Kurtosis:                       3.248   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === Nested Logit: IV-2SLS (price instrumented; clustered by country) ===
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:                      y   R-squared:                      0.7795
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.7788
# No. Observations:                4504   F-statistic:                 1.917e+18
# Date:                dom, nov 02 2025   P-value (F-stat)                0.0000
# Time:                        18:59:38   Distribution:                 chi2(15)
# Cov. Estimator:             clustered
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# Intercept                       -2.1234     1.3420    -1.5822     0.1136     -4.7538      0.5069
# averagescore                     0.1673     0.0515     3.2500     0.0012      0.0664      0.2682
# iap                              0.4939     0.1117     4.4220     0.0000      0.2750      0.7128
# ln_within                        0.9106     0.0091     100.26     0.0000      0.8928      0.9284
# C(country)[T.Canada]             0.2305     0.1327     1.7371     0.0824     -0.0296      0.4905
# C(country)[T.France]            -0.0047     0.1519    -0.0311     0.9752     -0.3025      0.2930
# C(country)[T.Germany]           -0.1290     0.0783    -1.6484     0.0993     -0.2824      0.0244
# C(country)[T.Italy]              0.0543     0.0333     1.6286     0.1034     -0.0110      0.1196
# C(country)[T.Japan]              0.3851     0.2759     1.3962     0.1627     -0.1555      0.9258
# C(country)[T.Korea]              0.2929     0.0800     3.6621     0.0003      0.1361      0.4496
# C(country)[T.Netherlands]       -0.0706     0.0022    -31.761     0.0000     -0.0750     -0.0662
# C(country)[T.Spain]             -0.1655     0.0279    -5.9308     0.0000     -0.2202     -0.1108
# C(country)[T.Sweden]            -0.1432     0.1059    -1.3515     0.1765     -0.3508      0.0645
# C(country)[T.United Kingdom]     0.1659     0.0296     5.5981     0.0000      0.1078      0.2240
# C(country)[T.United States]      0.1817     0.1287     1.4122     0.1579     -0.0705      0.4339
# price                            0.1147     0.2840     0.4039     0.6863     -0.4419      0.6712
# ================================================================================================
#
# Endogenous: price
# Instruments: Z_numapps
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 12
#
# === First Stage (price on Z + controls + ln_within + FE) ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     120.6
# Date:                dom, 02 nov 2025   Prob (F-statistic):           5.24e-09
# Time:                        18:59:38   Log-Likelihood:                -11661.
# No. Observations:                4504   AIC:                         2.335e+04
# Df Residuals:                    4488   BIC:                         2.346e+04
# Df Model:                          15
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.7407      0.346     10.808      0.000       3.062       4.419
# C(country)[T.Canada]             0.4404      0.008     56.611      0.000       0.425       0.456
# C(country)[T.France]             0.5140      0.011     46.454      0.000       0.492       0.536
# C(country)[T.Germany]            0.2579      0.006     42.450      0.000       0.246       0.270
# C(country)[T.Italy]             -0.1371      0.014     -9.616      0.000      -0.165      -0.109
# C(country)[T.Japan]              1.0288      0.021     49.329      0.000       0.988       1.070
# C(country)[T.Korea]              0.2245      0.028      8.134      0.000       0.170       0.279
# C(country)[T.Netherlands]       -0.0130      0.012     -1.082      0.279      -0.037       0.011
# C(country)[T.Spain]              0.0639      0.020      3.253      0.001       0.025       0.102
# C(country)[T.Sweden]             0.3426      0.018     18.734      0.000       0.307       0.378
# C(country)[T.United Kingdom]     0.0849      0.007     11.847      0.000       0.071       0.099
# C(country)[T.United States]      0.4137      0.013     31.416      0.000       0.388       0.440
# Z_numapps                        0.2854      0.102      2.792      0.005       0.085       0.486
# averagescore                    -0.1644      0.104     -1.578      0.115      -0.369       0.040
# iap                             -0.3324      0.088     -3.764      0.000      -0.506      -0.159
# ln_within                        0.0029      0.016      0.181      0.857      -0.029       0.035
# ==============================================================================
# Omnibus:                     2874.546   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41864.419
# Skew:                           2.841   Prob(JB):                         0.00
# Kurtosis:                      16.813   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# [First-stage] robust t(Z_numapps) = 2.79  →  robust F = 7.79
# [First-stage] partial R² (given controls+FE): 0.0029
#
# === Comparison table (Nested logit: OLS vs IV) ===
#        param  OLS_coef   OLS_se   IV_coef    IV_se
#    ln_within  0.910435 0.010232  0.910619 0.009083
#        price  0.002896 0.002724  0.114692 0.283963
# averagescore  0.149184 0.019401  0.167320 0.051483
#          iap  0.453099 0.042987  0.493875 0.111687
#    Intercept -1.612655 0.112584 -2.123429 1.342041
# c:\Users\guido\OneDrive\Documents\_EIO\empirical-IO-ps\venv\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 15, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# c:\Users\guido\OneDrive\Documents\_EIO\empirical-IO-ps\venv\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 15, but rank is 4
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# # Part II supply analysis
#
# 2.1 cost estimation

# %%
# Guido
df = pd.read_csv('../output/data/final_dataset.csv')
df.head()

#total market by country
df['total_market'] = df.groupby('country')['new_est'].transform('sum')
df['s_j'] = df['new_est'] / df['total_market']

#compute market share of outside good
outside_by_country = df[df['nest'].str.upper() == 'OUTSIDE'].groupby('country')['new_est'].sum()
df['Q_out'] = df['country'].map(outside_by_country)
df['s_0'] = df['Q_out'] / df['total_market']

df_us = df.loc[df['country'] == 'United States'].copy()
df_us = df_us[df_us['nest'].str.upper() != 'OUTSIDE'].copy() #remove outside good from dataset

epsilon = 1e-10  # avoid log(0)
df['y'] = np.log(df['s_j'].clip(lower=epsilon)) - np.log(df['s_0'].clip(lower=epsilon))



need = ["s_j", "price"]
df_us = df_us.replace([np.inf, -np.inf], np.nan).dropna(subset=need).copy()
df_us['y'] = np.log(df_us['s_j'].clip(lower=epsilon)) - np.log(df_us['s_0'].clip(lower=epsilon))

n = len(df_us)
p = df_us['price'].to_numpy().astype(float)

#retrieve alpha hat from previous estimation
alpha_hat = float(-0.4778) * (-1)  

#compute ownership matrix
firms = df_us['developer'].astype('category').cat.codes.to_numpy()
Omega_current = (firms[:, None] == firms[None, :]).astype(float)

#Compute Jacobian J = ds/dp
s = df_us['s_j'].to_numpy().astype(float)
outer_ss = np.outer(s, s) 
J = - alpha_hat * (np.diag(s) - outer_ss)

def calculate_markups(Omega, ownership): #define it to use it later in point 2.2
    #Markups from FOCs: 
    G = -(Omega * J)  # Hadamard product
    markup =  npl.solve(G, s)
    mc = p - markup
    pct = np.where(np.isfinite(markup / p), markup / p, np.nan)
    #Save marginal costs and markups
    df_summary = pd.DataFrame(
        {
            "ownership": ownership,
            "markup": markup,
            "mc": mc,
            "pct_markup": pct,
            "developer": df_us["developer"].to_numpy(),
            "app": df_us["app"].to_numpy(),
        },
        index=df_us.index,   # ensure 1:1 join on index
    )
    return df_summary
#attach marginal costs to df_us
df_us['mc'] = calculate_markups(Omega_current, "current")['mc'].to_numpy()
#same for markups
df_us['markup'] = calculate_markups(Omega_current, "current")['markup'].to_numpy()

#check own price elasticity
df_us['own_price_elast'] = alpha_hat * df_us['price'] * (1.0 - df_us['s_j'])

# %%
#make summary of df_us

summary = df_us[['markup','mc','own_price_elast']].agg(['mean','median','std', 'min','max'])
print(summary)
"""by_firm = None
if firm_col:
    by_firm = df_us.groupby(firm_col)[['markup','mc','pct_markup']].median().sort_values('pct_markup', ascending=False)

print("Overall (US) markup / cost summary:")
print(summary)

if by_firm is not None:
    print("\nMedian markup/cost by firm (US):")
    print(by_firm.head(100)) """
# Out:
#           markup         mc  own_price_elast
# mean    2.104248   2.118757         2.013477
# median  2.095473   1.294875         1.618033
# std     0.026289   3.601288         1.719660
# min     2.092927  -1.171780         0.458439
# max     2.474347  27.896365        14.325545
# 'by_firm = None\nif firm_col:\n    by_firm = df_us.groupby(firm_col)[[\'markup\',\'mc\',\'pct_markup\']].median().sort_values(\'pct_markup\', ascending=False)\n\nprint("Overall (US) markup / cost summary:")\nprint(summary)\n\nif by_firm is not None:\n    print("\nMedian markup/cost by firm (US):")\n    print(by_firm.head(100)) '

# %% [markdown]
# 2.2 markup estimation

# %%
#Guido

# Build Omega under three scenarios ---
n = len(df_us)

# Single-product
Omega_single = np.eye(n)

# Monopolist (everyone same owner)
Omega_monopoly = np.ones((n, n), dtype=float)

# --- 3) Compute markups ---
res_current = calculate_markups(Omega_current, 'current')
res_single  = calculate_markups(Omega_single, 'single')
res_monopoly = calculate_markups(Omega_monopoly, 'monopolist')

#append all three results together
res_all = pd.concat([res_current, res_single, res_monopoly], ignore_index=True)
#summarize results
summary_tbl = (res_all
    .groupby("ownership")
    .agg(markup_mean=('markup','mean'),
         markup_median=('markup','median'),
         mc_mean=('mc','mean'),
         mc_median=('mc','median'))
    .round(3)
)
print(summary_tbl)

#summary_tbl.to_latex("table_markups.tex", caption="Markup and marginal cost summaries", label="tab:markups")
# Out:
#             markup_mean  markup_median  mc_mean  mc_median
# ownership
# current           2.104          2.095    2.119      1.295
# monopolist       17.845         17.845  -13.622    -14.455
# single            2.098          2.094    2.125      1.295

# %%
"""# --- 1) Helpers ---
def ownership_matrix(ids):
    """Ω_{jk}=1 if same firm, else 0."""
    return (ids[:,None] == ids[None,:]).astype(float)

def markups_from_omega(dfm, alpha, Omega, ridge=1e-10):
    s = dfm['s_j'].to_numpy(float)
    p = dfm['price'].to_numpy(float)
    J = alpha * (np.diag(s) - np.outer(s, s))                  # ds/dp
    G = Omega * J                                              # Hadamard
    # Solve G m = -s
    try:
        m = -npl.solve(G, s)
    except npl.LinAlgError:
        m = -npl.solve(G + ridge*np.eye(len(s)), s)            # light ridge
    mc = p - m
    out = pd.DataFrame({'markup': m, 'mc': mc, 'price': p})
    out['pct_markup'] = np.where(np.isfinite(out['markup']/out['price']),
                                 out['markup']/out['price'], np.nan)
    return out

# --- 2) Build Ω under three scenarios ---
n = len(df_us)
# Current ownership
if firm_col is not None:
    firm_ids = df_us[firm_col].astype('category').cat.codes.to_numpy()
    Omega_current = ownership_matrix(firm_ids)
else:
    Omega_current = np.eye(n)   # if you don't have firm info, current==single-product

# Single-product
Omega_single = np.eye(n)

# Monopolist (everyone same owner)
Omega_mono = np.ones((n, n), dtype=float)

# --- 3) Compute markups ---
res_current = markups_from_omega(df_us, alpha_hat, Omega_current)
res_single  = markups_from_omega(df_us, alpha_hat, Omega_single)
res_mono    = markups_from_omega(df_us, alpha_hat, Omega_mono)


df_us = df_us.reset_index(drop=True)
res_current = res_current.reset_index(drop=True)
df_us[['mc', 'markup', 'pct_markup']] = res_current[['mc', 'markup', 'pct_markup']]


# --- 4) Summaries into a table ---
def summarize(dfm):
    return pd.Series({
        'markup_mean': dfm['markup'].mean(),
        'markup_median': dfm['markup'].median(),
        'pct_markup_mean': dfm['pct_markup'].mean(),
        'pct_markup_median': dfm['pct_markup'].median(),
        'mc_median': dfm['mc'].median()
    })

summary_tbl = pd.concat({
    'Current ownership': summarize(res_current),
    'Single-product':    summarize(res_single),
    'Monopolist':        summarize(res_mono),
}, axis=1)

print("\n=== Markups under alternative ownership (US, Berry-logit) ===")
print(summary_tbl.round(3).to_string()) """
# Out:
# === Markups under alternative ownership (US, Berry-logit) ===
#                    Current ownership  Single-product  Monopolist
# markup_mean                    2.104           2.098      17.845
# markup_median                  2.095           2.094      17.845
# pct_markup_mean                0.831           0.829       7.053
# pct_markup_median              0.619           0.619       5.268
# mc_median                      1.295           1.295     -14.455

# %% [markdown]
# 2.3 merger simulation

# %%
#merger simulation
y = df_us['y']


def shares_logit(p_vec: np.ndarray) -> np.ndarray:
    util = y 
    expu = np.exp(util)
    denom = 1.0 + np.sum(expu)
    return expu / denom #return the shares

def compute_jacobian(s: np.ndarray) -> np.ndarray:
    outer_ss = np.outer(s, s)
    J = - alpha_hat * (np.diag(s) - outer_ss)  # shape (n,n)
    return J

def solve_nevo_eq5(mc_vec, Omega, p_init=None, tol:float=1e-3, max_iter:int=1000, damping=0.6):
    """
    Solve Nevo (2000) equation (5):
        s(p) + (Ω ⊙ J(p)) (p - mc) = 0
    for equilibrium prices p.
    
    Args:
        mc_vec:   Marginal costs for each product.
        Omega:    Ownership matrix, where Ω[j,k] = 1 if products j and k are jointly owned.
        p_init:   Initial price vector. If None, it will use df_us['price'].
        tol:      Convergence tolerance for FOC residuals.
        max_iter: Maximum number of iterations.
        damping:  Relaxation factor (0.4–0.8 recommended).
    """
    # if no initial guess provided, start from your observed prices in df_us
    p = df_us["price"].to_numpy(float).copy() if p_init is None else np.array(p_init, float).copy()
    
    for i in range(max_iter):
        # Compute current market shares under current prices
        s_now = shares_logit(p)
        
        # Compute Jacobian ds/dp under simple logit
        J_now = compute_jacobian(s_now)

        # Step 3: Hadamard product
        G = -(Omega * J_now)

        # Step 4: fixed-point mapping -> solve G * step = s
        step = npl.solve(G, s_now)
        p_new = mc_vec + step

        # Step 5: apply damping (helps convergence)
        p = (1 - damping) * p + damping * p_new

        # Step 6: compute FOC residuals F(p) = s + (Ω⊙J)(p - mc)
        res = s_now + (Omega * J_now) @ (p - mc_vec)
        # Step 7: check convergence
        if np.max(np.abs(res)) < tol:
            print(f"Converged in {i+1} iterations, max residual = {np.max(np.abs(res)):.2e}")
            return p, True

    # If not converged
    print("Did not converge; try increasing max_iter or adjusting damping.")
    return p, False

#simulate merger
unique_developers = df_us['developer'].unique()
targets = [f for f in unique_developers if f != 'Mojang']

rows = []
for j, t in enumerate(targets):
    print('target number', j,'/',len(targets), ': ', t)
    # Make a copy of the us_market DataFrame for the current developer
    developer_data = df_us.copy()
    #update name of t to mojang
    developer_data.loc[developer_data['developer'] == t, 'developer'] = 'Mojang'

    #compute Omega under this ownership structure
    firms = developer_data['developer'].astype('category').cat.codes.to_numpy()
    Omega_post = (firms[:, None] == firms[None, :]).astype(float)
    #solve for new prices
    p_eq, converged = solve_nevo_eq5(
        mc_vec=df_us['mc'].to_numpy(float),
        Omega=Omega_post,
        p_init=df_us['price'].to_numpy(float),
        tol=1e-5,
        max_iter=1000,
        damping=0.5
    )
    #store results and profits
    mojang_mask = developer_data['developer'].eq('Mojang').to_numpy()
    rows.append({"target": t, "converged": bool(converged),
             "mojang_prices": p_eq[mojang_mask].tolist(),
             "mojang_profit": float(np.sum((p_eq - df_us['mc'].to_numpy(float)) * shares_logit(p_eq) * mojang_mask))}) #to check if shares are correct
# Out:
# target number 0 / 282 :  Catana Comics
# Converged in 1 iterations, max residual = 3.15e-06
# target number 1 / 282 :  Toca Boca
# Converged in 8 iterations, max residual = 5.17e-06
# target number 2 / 282 :  XtraMath
# Converged in 5 iterations, max residual = 8.67e-06
# target number 3 / 282 :  Aviation Supplies & Academics
# Converged in 3 iterations, max residual = 5.71e-06
# target number 4 / 282 :  TMI Media, LLC
# Converged in 1 iterations, max residual = 5.99e-06
# target number 5 / 282 :  The Japan Times Publishing
# Converged in 1 iterations, max residual = 2.81e-06
# target number 6 / 282 :  Signal Stuff
# Converged in 1 iterations, max residual = 7.26e-07
# target number 7 / 282 :  Sago Mini
# Converged in 1 iterations, max residual = 3.52e-06
# target number 8 / 282 :  TSO (The Stationery Office)
# Converged in 1 iterations, max residual = 5.26e-07
# target number 9 / 282 :  August Software
# Converged in 3 iterations, max residual = 5.05e-06
# target number 10 / 282 :  Vito Technology
# Converged in 5 iterations, max residual = 5.60e-06
# target number 11 / 282 :  Classical Conversations Inc
# Converged in 1 iterations, max residual = 1.10e-06
# target number 12 / 282 :  Noctua Software
# Converged in 5 iterations, max residual = 5.76e-06
# target number 13 / 282 :  ForceReadiness.com
# Converged in 1 iterations, max residual = 7.09e-06
# target number 14 / 282 :  Inception Mobile.
# Converged in 1 iterations, max residual = 1.22e-06
# target number 15 / 282 :  Dan Russell-Pinson
# Converged in 5 iterations, max residual = 5.52e-06
# target number 16 / 282 :  Terminal Eleven
# Converged in 5 iterations, max residual = 8.47e-06
# target number 17 / 282 :  Unbroken Software, LLC
# Converged in 1 iterations, max residual = 9.47e-07
# target number 18 / 282 :  beadybiddle
# Converged in 1 iterations, max residual = 8.81e-06
# target number 19 / 282 :  ForTheLoss Games
# Converged in 1 iterations, max residual = 4.02e-06
# target number 20 / 282 :  GordonEdwards.net LLC
# Converged in 5 iterations, max residual = 8.23e-06
# target number 21 / 282 :  Spud Pickles
# Converged in 3 iterations, max residual = 7.65e-06
# target number 22 / 282 :  IncorporateApps
# Converged in 5 iterations, max residual = 9.32e-06
# target number 23 / 282 :  Mad Scientist
# Converged in 4 iterations, max residual = 9.84e-06
# target number 24 / 282 :  MRE Programming
# Converged in 1 iterations, max residual = 5.03e-06
# target number 25 / 282 :  Exelerus Apps
# Converged in 3 iterations, max residual = 5.82e-06
# target number 26 / 282 :  DarkFox Labs
# Converged in 1 iterations, max residual = 8.85e-06
# target number 27 / 282 :  ZomboDroid
# Converged in 5 iterations, max residual = 7.70e-06
# target number 28 / 282 :  Ciskro Apps
# Converged in 1 iterations, max residual = 4.18e-06
# target number 29 / 282 :  MediaVibe
# Converged in 3 iterations, max residual = 7.08e-06
# target number 30 / 282 :  ClockworkMod
# Converged in 6 iterations, max residual = 6.33e-06
# target number 31 / 282 :  This American Life
# Converged in 4 iterations, max residual = 8.39e-06
# target number 32 / 282 :  Rockstar Games
# Converged in 10 iterations, max residual = 7.56e-06
# target number 33 / 282 :  TENBIRDS
# Converged in 1 iterations, max residual = 5.76e-06
# target number 34 / 282 :  Scott Cawthon
# Converged in 6 iterations, max residual = 9.31e-06
# target number 35 / 282 :  Oddworld Inhabitants Inc
# Converged in 5 iterations, max residual = 5.36e-06
# target number 36 / 282 :  Mika Mobile
# Converged in 3 iterations, max residual = 6.50e-06
# target number 37 / 282 :  Activision Publishing, Inc.
# Converged in 5 iterations, max residual = 8.25e-06
# target number 38 / 282 :  Coffee Stain Publishing
# Converged in 8 iterations, max residual = 9.91e-06
# target number 39 / 282 :  Bethesda Softworks LLC
# Converged in 2 iterations, max residual = 5.22e-06
# target number 40 / 282 :  Clickteam USA LLC
# Converged in 9 iterations, max residual = 5.46e-06
# target number 41 / 282 :  Cartoon Network
# Converged in 8 iterations, max residual = 9.51e-06
# target number 42 / 282 :  Blazes
# Converged in 1 iterations, max residual = 5.03e-08
# target number 43 / 282 :  Outerminds Inc.
# Converged in 4 iterations, max residual = 5.02e-06
# target number 44 / 282 :  Warner Bros. International Enterprises
# Converged in 9 iterations, max residual = 6.26e-06
# target number 45 / 282 :  NEKKI
# Converged in 6 iterations, max residual = 8.43e-06
# target number 46 / 282 :  Reliance Big Entertainment (UK) Private Limited
# Converged in 6 iterations, max residual = 6.35e-06
# target number 47 / 282 :  Ubisoft Entertainment
# Converged in 9 iterations, max residual = 6.79e-06
# target number 48 / 282 :  Bravestars Games
# Converged in 9 iterations, max residual = 8.23e-06
# target number 49 / 282 :  Gameloft SE
# Converged in 7 iterations, max residual = 6.88e-06
# target number 50 / 282 :  SQUARE ENIX Ltd
# Converged in 10 iterations, max residual = 5.49e-06
# target number 51 / 282 :  Henrik RydgÃ¥rd
# Converged in 5 iterations, max residual = 6.04e-06
# target number 52 / 282 :  Young Horses
# Converged in 4 iterations, max residual = 8.90e-06
# target number 53 / 282 :  Jesse Makkonen
# Converged in 2 iterations, max residual = 7.52e-06
# target number 54 / 282 :  Candy Rufus Games
# Converged in 4 iterations, max residual = 7.80e-06
# target number 55 / 282 :  Amanita Design
# Converged in 3 iterations, max residual = 8.39e-06
# target number 56 / 282 :  505 Games Srl
# Converged in 9 iterations, max residual = 5.44e-06
# target number 57 / 282 :  Joey Drew Studios
# Converged in 3 iterations, max residual = 6.69e-06
# target number 58 / 282 :  Robot Gentleman
# Converged in 5 iterations, max residual = 7.96e-06
# target number 59 / 282 :  BonusXP, Inc.
# Converged in 1 iterations, max residual = 9.72e-07
# target number 60 / 282 :  Klei Entertainment Inc.
# Converged in 6 iterations, max residual = 7.82e-06
# target number 61 / 282 :  DevolverDigital
# Converged in 6 iterations, max residual = 9.23e-06
# target number 62 / 282 :  Hitcents
# Converged in 5 iterations, max residual = 6.59e-06
# target number 63 / 282 :  Invictus Studio
# Converged in 5 iterations, max residual = 5.15e-06
# target number 64 / 282 :  Buff Studio Co.,Ltd.
# Converged in 1 iterations, max residual = 3.56e-06
# target number 65 / 282 :  Butterscotch Shenanigans
# Converged in 4 iterations, max residual = 8.42e-06
# target number 66 / 282 :  Playdead
# Converged in 6 iterations, max residual = 6.59e-06
# target number 67 / 282 :  PRIDEGAMESSTUDIO OU PLC
# Converged in 8 iterations, max residual = 5.29e-06
# target number 68 / 282 :  Headup
# Converged in 6 iterations, max residual = 5.74e-06
# target number 69 / 282 :  Disney
# Converged in 8 iterations, max residual = 8.08e-06
# target number 70 / 282 :  SQUARE ENIX Co.,Ltd.
# Converged in 8 iterations, max residual = 5.89e-06
# target number 71 / 282 :  Rusty Lake
# Converged in 6 iterations, max residual = 6.20e-06
# target number 72 / 282 :  Creative Mobile Games
# Converged in 2 iterations, max residual = 7.32e-06
# target number 73 / 282 :  Fast Emulator
# Converged in 5 iterations, max residual = 8.04e-06
# target number 74 / 282 :  SNK CORPORATION
# Converged in 6 iterations, max residual = 6.50e-06
# target number 75 / 282 :  Hemisphere Games Inc
# Converged in 6 iterations, max residual = 6.17e-06
# target number 76 / 282 :  Bolt Creative, Inc
# Converged in 6 iterations, max residual = 7.71e-06
# target number 77 / 282 :  Halfbrick Studios
# Converged in 8 iterations, max residual = 9.29e-06
# target number 78 / 282 :  FlukeDude
# Converged in 5 iterations, max residual = 9.77e-06
# target number 79 / 282 :  RobTop Games
# Converged in 9 iterations, max residual = 5.46e-06
# target number 80 / 282 :  epsxe software s.l.
# Converged in 9 iterations, max residual = 5.18e-06
# target number 81 / 282 :  SEGA
# Converged in 5 iterations, max residual = 5.24e-06
# target number 82 / 282 :  AZAMATIKA
# Converged in 5 iterations, max residual = 8.00e-06
# target number 83 / 282 :  Terry Cavanagh
# Converged in 3 iterations, max residual = 7.02e-06
# target number 84 / 282 :  Team 17 Digital Limited
# Converged in 8 iterations, max residual = 6.37e-06
# target number 85 / 282 :  Asmodee Digital
# Converged in 6 iterations, max residual = 6.29e-06
# target number 86 / 282 :  AI Factory Limited
# Converged in 5 iterations, max residual = 6.23e-06
# target number 87 / 282 :  Marmalade Game Studio
# Converged in 7 iterations, max residual = 7.02e-06
# target number 88 / 282 :  CGE digital
# Converged in 2 iterations, max residual = 6.54e-06
# target number 89 / 282 :  USM
# Converged in 6 iterations, max residual = 5.52e-06
# target number 90 / 282 :  Slothwerks
# Converged in 1 iterations, max residual = 9.90e-06
# target number 91 / 282 :  Playdigious
# Converged in 2 iterations, max residual = 5.25e-06
# target number 92 / 282 :  Nomad Games
# Converged in 1 iterations, max residual = 5.38e-07
# target number 93 / 282 :  Exploding Kittens
# Converged in 5 iterations, max residual = 8.54e-06
# target number 94 / 282 :  Fabled Game
# Converged in 3 iterations, max residual = 6.71e-06
# target number 95 / 282 :  Tomorrow Corporation
# Converged in 4 iterations, max residual = 6.18e-06
# target number 96 / 282 :  Jazza Studios
# Converged in 3 iterations, max residual = 6.79e-06
# target number 97 / 282 :  Infinite Dreams
# Converged in 4 iterations, max residual = 9.24e-06
# target number 98 / 282 :  Kairosoft Co.,Ltd
# Converged in 6 iterations, max residual = 5.22e-06
# target number 99 / 282 :  CLEVERBIT
# Converged in 1 iterations, max residual = 1.84e-06
# target number 100 / 282 :  Teach Monster Games Limited
# Converged in 5 iterations, max residual = 8.11e-06
# target number 101 / 282 :  PBS KIDS
# Converged in 2 iterations, max residual = 7.49e-06
# target number 102 / 282 :  My Town Games Ltd
# Converged in 1 iterations, max residual = 2.81e-07
# target number 103 / 282 :  Intellijoy Educational Games for Kids
# Converged in 3 iterations, max residual = 7.25e-06
# target number 104 / 282 :  X.D. Network
# Converged in 5 iterations, max residual = 6.89e-06
# target number 105 / 282 :  So Far So Good
# Converged in 5 iterations, max residual = 6.78e-06
# target number 106 / 282 :  Big Blue Bubble
# Converged in 2 iterations, max residual = 6.18e-06
# target number 107 / 282 :  Rayark International Limited
# Converged in 8 iterations, max residual = 9.25e-06
# target number 108 / 282 :  MontanaGames
# Converged in 1 iterations, max residual = 6.29e-06
# target number 109 / 282 :  Annapurna Interactive
# Converged in 2 iterations, max residual = 9.83e-06
# target number 110 / 282 :  SQUARE ENIX LTD
# Converged in 7 iterations, max residual = 7.06e-06
# target number 111 / 282 :  JoyBits Co. Ltd.
# Converged in 5 iterations, max residual = 5.98e-06
# target number 112 / 282 :  CottonGame
# Converged in 2 iterations, max residual = 5.09e-06
# target number 113 / 282 :  Fireproof Games
# Converged in 9 iterations, max residual = 9.90e-06
# target number 114 / 282 :  Blue Brain Games s.r.o.
# Converged in 5 iterations, max residual = 6.10e-06
# target number 115 / 282 :  Afterburn
# Converged in 1 iterations, max residual = 7.32e-06
# target number 116 / 282 :  Brainium Studios
# Converged in 1 iterations, max residual = 3.04e-06
# target number 117 / 282 :  Bart Bonte
# Converged in 2 iterations, max residual = 7.02e-06
# target number 118 / 282 :  ustwo games
# Converged in 8 iterations, max residual = 9.59e-06
# target number 119 / 282 :  Blue Wizard Digital LP
# Converged in 4 iterations, max residual = 5.36e-06
# target number 120 / 282 :  Vector Unit
# Converged in 4 iterations, max residual = 5.84e-06
# target number 121 / 282 :  ELECTRONIC ARTS
# Converged in 8 iterations, max residual = 9.38e-06
# target number 122 / 282 :  Not Doppler
# Converged in 8 iterations, max residual = 8.33e-06
# target number 123 / 282 :  Bennett Racing Simulations, LLC
# Converged in 3 iterations, max residual = 5.47e-06
# target number 124 / 282 :  Top Free Games.
# Converged in 5 iterations, max residual = 5.22e-06
# target number 125 / 282 :  Playsport Games
# Converged in 5 iterations, max residual = 7.28e-06
# target number 126 / 282 :  Real Games srls
# Converged in 6 iterations, max residual = 6.44e-06
# target number 127 / 282 :  HandyGames
# Converged in 3 iterations, max residual = 9.24e-06
# target number 128 / 282 :  Chucklefish Limited
# Converged in 5 iterations, max residual = 8.68e-06
# target number 129 / 282 :  ZigZaGame Inc.
# Converged in 5 iterations, max residual = 7.84e-06
# target number 130 / 282 :  CAPCOM CO., LTD.
# Converged in 3 iterations, max residual = 5.12e-06
# target number 131 / 282 :  Ninetail Games
# Converged in 4 iterations, max residual = 8.17e-06
# target number 132 / 282 :  Trese Brothers
# Converged in 1 iterations, max residual = 7.11e-06
# target number 133 / 282 :  inkle Ltd
# Converged in 3 iterations, max residual = 9.69e-06
# target number 134 / 282 :  KEMCO
# Converged in 1 iterations, max residual = 3.46e-07
# target number 135 / 282 :  ilmfinity
# Converged in 5 iterations, max residual = 6.37e-06
# target number 136 / 282 :  Amir Rajan
# Converged in 3 iterations, max residual = 8.50e-06
# target number 137 / 282 :  tltGames
# Converged in 4 iterations, max residual = 6.66e-06
# target number 138 / 282 :  Beamdog
# Converged in 5 iterations, max residual = 5.09e-06
# target number 139 / 282 :  NTT Resonant Inc.
# Converged in 6 iterations, max residual = 6.26e-06
# target number 140 / 282 :  Freetime Game
# Converged in 5 iterations, max residual = 5.80e-06
# target number 141 / 282 :  EtherGaming
# Converged in 3 iterations, max residual = 6.20e-06
# target number 142 / 282 :  Aspyr Media, Inc.
# Converged in 6 iterations, max residual = 8.21e-06
# target number 143 / 282 :  Abyte Entertainment
# Converged in 1 iterations, max residual = 6.36e-06
# target number 144 / 282 :  Everybody House Games
# Converged in 1 iterations, max residual = 8.55e-06
# target number 145 / 282 :  Atari, Inc.
# Converged in 2 iterations, max residual = 6.47e-06
# target number 146 / 282 :  PocketLabs
# Converged in 1 iterations, max residual = 6.54e-06
# target number 147 / 282 :  U-Play Online
# Converged in 5 iterations, max residual = 5.40e-06
# target number 148 / 282 :  GIANTS Software
# Converged in 7 iterations, max residual = 5.68e-06
# target number 149 / 282 :  Greenheart Games
# Converged in 5 iterations, max residual = 8.13e-06
# target number 150 / 282 :  Jundroo, LLC
# Converged in 5 iterations, max residual = 6.84e-06
# target number 151 / 282 :  Dinosaur Polo Club
# Converged in 6 iterations, max residual = 8.71e-06
# target number 152 / 282 :  astragon Entertainment GmbH
# Converged in 3 iterations, max residual = 5.70e-06
# target number 153 / 282 :  RORTOS
# Converged in 5 iterations, max residual = 8.18e-06
# target number 154 / 282 :  Infinite Flight LLC
# Converged in 6 iterations, max residual = 7.17e-06
# target number 155 / 282 :  Codebrew Games
# Converged in 5 iterations, max residual = 6.93e-06
# target number 156 / 282 :  Pavel Dobryakov
# Converged in 3 iterations, max residual = 7.02e-06
# target number 157 / 282 :  11 bit studios
# Converged in 5 iterations, max residual = 8.78e-06
# target number 158 / 282 :  Super Emulation
# Converged in 1 iterations, max residual = 7.67e-07
# target number 159 / 282 :  Games Operators S.A.
# Converged in 3 iterations, max residual = 5.88e-06
# target number 160 / 282 :  ClockStone STUDIO
# Converged in 6 iterations, max residual = 8.78e-06
# target number 161 / 282 :  Noodlecake Studios Inc
# Converged in 3 iterations, max residual = 5.73e-06
# target number 162 / 282 :  Kalypso Media Mobile GmbH
# Converged in 2 iterations, max residual = 5.23e-06
# target number 163 / 282 :  Dry Cactus Limited
# Converged in 5 iterations, max residual = 8.03e-06
# target number 164 / 282 :  Bowen Games LLC
# Converged in 1 iterations, max residual = 5.30e-06
# target number 165 / 282 :  Mageeks Apps & Games
# Converged in 3 iterations, max residual = 5.63e-06
# target number 166 / 282 :  2K, Inc.
# Converged in 6 iterations, max residual = 7.17e-06
# target number 167 / 282 :  Flipline Studios
# Converged in 7 iterations, max residual = 5.03e-06
# target number 168 / 282 :  Åukasz Jakowski
# Converged in 5 iterations, max residual = 8.89e-06
# target number 169 / 282 :  Ironhide Game Studio
# Converged in 9 iterations, max residual = 5.31e-06
# target number 170 / 282 :  Hammerfall Publishing Global
# Converged in 2 iterations, max residual = 8.28e-06
# target number 171 / 282 :  ninja kiwi
# Converged in 9 iterations, max residual = 9.47e-06
# target number 172 / 282 :  Konfa Games
# Converged in 2 iterations, max residual = 5.91e-06
# target number 173 / 282 :  ChengDu LongYou Tech
# Converged in 1 iterations, max residual = 8.76e-06
# target number 174 / 282 :  EasyTech
# Converged in 2 iterations, max residual = 6.16e-06
# target number 175 / 282 :  The Men Who Wear Many Hats LLC
# Converged in 4 iterations, max residual = 7.68e-06
# target number 176 / 282 :  Open Lab Games
# Converged in 1 iterations, max residual = 1.40e-07
# target number 177 / 282 :  Blindflug Studios AG
# Converged in 5 iterations, max residual = 5.06e-06
# target number 178 / 282 :  Repos Production
# Converged in 1 iterations, max residual = 2.99e-06
# target number 179 / 282 :  KillHouse Games
# Converged in 5 iterations, max residual = 7.15e-06
# target number 180 / 282 :  Nuclear.Unicorn
# Converged in 2 iterations, max residual = 6.00e-06
# target number 181 / 282 :  GameCoaster
# Converged in 4 iterations, max residual = 9.10e-06
# target number 182 / 282 :  Corroding games
# Converged in 5 iterations, max residual = 8.62e-06
# target number 183 / 282 :  Northway Games
# Converged in 2 iterations, max residual = 8.92e-06
# target number 184 / 282 :  Jolly Pixel
# Converged in 2 iterations, max residual = 5.46e-06
# target number 185 / 282 :  Raw Fury
# Converged in 2 iterations, max residual = 8.20e-06
# target number 186 / 282 :  Sporcle, Inc
# Converged in 3 iterations, max residual = 8.27e-06
# target number 187 / 282 :  Etermax
# Converged in 6 iterations, max residual = 8.39e-06
# target number 188 / 282 :  Team Jet
# Converged in 4 iterations, max residual = 7.23e-06
# target number 189 / 282 :  Algoriddim
# Converged in 4 iterations, max residual = 9.87e-06
# target number 190 / 282 :  Audiophile
# Converged in 4 iterations, max residual = 8.22e-06
# target number 191 / 282 :  eXtream Software Development
# Converged in 5 iterations, max residual = 5.53e-06
# target number 192 / 282 :  Roni Music
# Converged in 1 iterations, max residual = 6.43e-06
# target number 193 / 282 :  Bitcount ltd.
# Converged in 3 iterations, max residual = 8.16e-06
# target number 194 / 282 :  Technimo
# Converged in 5 iterations, max residual = 7.37e-06
# target number 195 / 282 :  KhaosTechSoftwareSln
# Converged in 1 iterations, max residual = 4.97e-07
# target number 196 / 282 :  Rhythm Software
# Converged in 2 iterations, max residual = 7.83e-06
# target number 197 / 282 :  TonalEnergy, Inc
# Converged in 5 iterations, max residual = 8.52e-06
# target number 198 / 282 :  FifthSource
# Converged in 4 iterations, max residual = 9.78e-06
# target number 199 / 282 :  Scott Rundell
# Converged in 1 iterations, max residual = 7.41e-06
# target number 200 / 282 :  Zubersoft
# Converged in 2 iterations, max residual = 8.35e-06
# target number 201 / 282 :  acme-android.com
# Converged in 2 iterations, max residual = 7.96e-06
# target number 202 / 282 :  quality apps (recorder, weather, music)
# Converged in 5 iterations, max residual = 7.06e-06
# target number 203 / 282 :  TuneIn Inc
# Converged in 6 iterations, max residual = 9.63e-06
# target number 204 / 282 :  Image-Line
# Converged in 5 iterations, max residual = 8.32e-06
# target number 205 / 282 :  Max MP
# Converged in 9 iterations, max residual = 5.14e-06
# target number 206 / 282 :  TeslaCoil Software
# Converged in 9 iterations, max residual = 5.35e-06
# target number 207 / 282 :  JustNewDesigns
# Converged in 3 iterations, max residual = 5.92e-06
# target number 208 / 282 :  UNVOID
# Converged in 1 iterations, max residual = 5.01e-06
# target number 209 / 282 :  Ahmed Bousrih
# Converged in 1 iterations, max residual = 1.19e-07
# target number 210 / 282 :  myAP Devs
# Converged in 1 iterations, max residual = 9.91e-07
# target number 211 / 282 :  Studio eXtreme
# Converged in 3 iterations, max residual = 7.99e-06
# target number 212 / 282 :  Edzon DM
# Converged in 2 iterations, max residual = 7.69e-06
# target number 213 / 282 :  androidslide
# Converged in 4 iterations, max residual = 8.25e-06
# target number 214 / 282 :  ChYK the dev.
# Converged in 1 iterations, max residual = 4.39e-06
# target number 215 / 282 :  LeeDrOiD
# Converged in 1 iterations, max residual = 1.14e-06
# target number 216 / 282 :  Design Bench â Immersive Agency
# Converged in 1 iterations, max residual = 7.28e-07
# target number 217 / 282 :  Beach Road IT
# Converged in 1 iterations, max residual = 7.34e-06
# target number 218 / 282 :  RandomVector
# Converged in 1 iterations, max residual = 1.63e-06
# target number 219 / 282 :  KRISHNA AR
# Converged in 1 iterations, max residual = 4.20e-07
# target number 220 / 282 :  KushJain
# Converged in 1 iterations, max residual = 2.43e-06
# target number 221 / 282 :  ppick CH.
# Converged in 1 iterations, max residual = 1.26e-06
# target number 222 / 282 :  Patryk Goworowski
# Converged in 1 iterations, max residual = 2.19e-06
# target number 223 / 282 :  21MaRcO12
# Converged in 1 iterations, max residual = 4.59e-06
# target number 224 / 282 :  Nate Wren Design
# Converged in 3 iterations, max residual = 6.41e-06
# target number 225 / 282 :  OFTN Inc.
# Converged in 2 iterations, max residual = 5.01e-06
# target number 226 / 282 :  Pujie
# Converged in 4 iterations, max residual = 7.43e-06
# target number 227 / 282 :  Ciao Studio
# Converged in 1 iterations, max residual = 6.10e-06
# target number 228 / 282 :  Francisco Alcala and Wilson So
# Converged in 1 iterations, max residual = 7.27e-06
# target number 229 / 282 :  HotSchedules
# Converged in 6 iterations, max residual = 8.78e-06
# target number 230 / 282 :  Bullet Journal
# Converged in 1 iterations, max residual = 4.32e-06
# target number 231 / 282 :  Ndemic Creations
# Converged in 3 iterations, max residual = 5.58e-06
# target number 232 / 282 :  WriteOn
# Converged in 1 iterations, max residual = 8.97e-06
# target number 233 / 282 :  YCdroid
# Converged in 1 iterations, max residual = 1.41e-06
# target number 234 / 282 :  Digibites
# Converged in 4 iterations, max residual = 6.12e-06
# target number 235 / 282 :  PishroDevs
# Converged in 1 iterations, max residual = 1.53e-06
# target number 236 / 282 :  INTSIG
# Converged in 8 iterations, max residual = 9.32e-06
# target number 237 / 282 :  Digipom
# Converged in 5 iterations, max residual = 8.06e-06
# target number 238 / 282 :  NLL
# Converged in 5 iterations, max residual = 8.78e-06
# target number 239 / 282 :  Bret H. Hardman
# Converged in 1 iterations, max residual = 9.95e-06
# target number 240 / 282 :  LYL Studio
# Converged in 5 iterations, max residual = 6.01e-06
# target number 241 / 282 :  Quky
# Converged in 1 iterations, max residual = 2.92e-06
# target number 242 / 282 :  Pavel Rekun
# Converged in 1 iterations, max residual = 1.02e-06
# target number 243 / 282 :  M2Catalyst, LLC.
# Converged in 3 iterations, max residual = 6.26e-06
# target number 244 / 282 :  HiPER Development Studio
# Converged in 4 iterations, max residual = 6.58e-06
# target number 245 / 282 :  plusnow dev.
# Converged in 1 iterations, max residual = 9.15e-06
# target number 246 / 282 :  SkyPaw Co.,Ltd
# Converged in 1 iterations, max residual = 1.47e-06
# target number 247 / 282 :  Calculated Industries
# Converged in 3 iterations, max residual = 6.53e-06
# target number 248 / 282 :  Dmac Mobile Developments, LLC
# Converged in 1 iterations, max residual = 3.08e-06
# target number 249 / 282 :  MyScript
# Converged in 4 iterations, max residual = 5.64e-06
# target number 250 / 282 :  Anti Spy Mobile
# Converged in 2 iterations, max residual = 8.19e-06
# target number 251 / 282 :  Kustom Industries
# Converged in 6 iterations, max residual = 5.92e-06
# target number 252 / 282 :  Panda Gaming Studio
# Converged in 5 iterations, max residual = 7.76e-06
# target number 253 / 282 :  wakdev
# Converged in 5 iterations, max residual = 6.58e-06
# target number 254 / 282 :  Jiri Techet
# Converged in 5 iterations, max residual = 5.70e-06
# target number 255 / 282 :  Tiny Watch
# Converged in 1 iterations, max residual = 2.81e-08
# target number 256 / 282 :  PixelCurves
# Converged in 3 iterations, max residual = 6.14e-06
# target number 257 / 282 :  joaomgcd
# Converged in 9 iterations, max residual = 5.27e-06
# target number 258 / 282 :  JW Dev;
# Converged in 1 iterations, max residual = 8.30e-07
# target number 259 / 282 :  Codingcode
# Converged in 6 iterations, max residual = 6.87e-06
# target number 260 / 282 :  Best App - Top Droid Team
# Converged in 8 iterations, max residual = 6.18e-06
# target number 261 / 282 :  Alex Savin
# Converged in 2 iterations, max residual = 9.17e-06
# target number 262 / 282 :  darken
# Converged in 6 iterations, max residual = 7.57e-06
# target number 263 / 282 :  Cory Charlton
# Converged in 1 iterations, max residual = 1.11e-06
# target number 264 / 282 :  Defiant Technologies, LLC
# Converged in 5 iterations, max residual = 6.28e-06
# target number 265 / 282 :  Sam Ruston
# Converged in 1 iterations, max residual = 7.84e-06
# target number 266 / 282 :  Georg Lukas
# Converged in 1 iterations, max residual = 4.37e-06
# target number 267 / 282 :  Appliqato
# Converged in 5 iterations, max residual = 6.31e-06
# target number 268 / 282 :  Unified Intents
# Converged in 6 iterations, max residual = 5.62e-06
# target number 269 / 282 :  Informed Publishing
# Converged in 1 iterations, max residual = 1.40e-06
# target number 270 / 282 :  dwitherell
# Converged in 2 iterations, max residual = 5.89e-06
# target number 271 / 282 :  webappvn
# Converged in 1 iterations, max residual = 5.17e-07
# target number 272 / 282 :  Abdelrahman M. Sid
# Converged in 2 iterations, max residual = 5.42e-06
# target number 273 / 282 :  Cranston McIntosh
# Converged in 1 iterations, max residual = 8.49e-06
# target number 274 / 282 :  SyncTech Pty Ltd
# Converged in 1 iterations, max residual = 9.17e-06
# target number 275 / 282 :  BitTorrent, Inc.
# Converged in 5 iterations, max residual = 6.66e-06
# target number 276 / 282 :  J2 Interactive
# Converged in 8 iterations, max residual = 8.66e-06
# target number 277 / 282 :  2kit consulting
# Converged in 2 iterations, max residual = 8.23e-06
# target number 278 / 282 :  QuVideo Inc. Best Video Editor & Video Maker App
# Converged in 6 iterations, max residual = 6.34e-06
# target number 279 / 282 :  Perspective Software
# Converged in 2 iterations, max residual = 9.38e-06
# target number 280 / 282 :  Tiny Solutions LLC
# Converged in 5 iterations, max residual = 6.76e-06
# target number 281 / 282 :  Homesoft, LLC
# Converged in 6 iterations, max residual = 5.10e-06

# %%
df_results = pd.DataFrame(rows)
df_results.sort_values(by='mojang_profit', ascending=False)
# Out:
#                 target  converged  \
# 32      Rockstar Games       True
# 113    Fireproof Games       True
# 50     SQUARE ENIX Ltd       True
# 171         ninja kiwi       True
# 48    Bravestars Games       True
# ..                 ...        ...
# 102  My Town Games Ltd       True
# 176     Open Lab Games       True
# 209      Ahmed Bousrih       True
# 42              Blazes       True
# 255         Tiny Watch       True
#
#                                          mojang_prices  mojang_profit
# 32   [5.414185732366245, 7.414185732366246, 7.41418...       0.529716
# 113  [7.086628854730549, 2.398585098125068, 1.39858...       0.478184
# 50             [1.3980425123550182, 7.083506561421336]       0.474993
# 171  [7.082316611735774, 3.397322032267666, 5.39732...       0.473866
# 48             [1.3906385852754748, 7.059405016050848]       0.450923
# ..                                                 ...            ...
# 102            [6.990004509339033, 3.1807117720834364]       0.381429
# 176             [6.9900022546654075, 6.18071113054163]       0.381425
# 209            [6.990001916465072, 2.1807110343106384]       0.381424
# 42             [1.6807107188873376, 6.990000807920796]       0.381422
# 255             [6.990000450932424, 2.180710617310521]       0.381422
#
# [282 rows x 4 columns]

# %%
"""import numpy as np
import pandas as pd
import numpy.linalg as npl

# 0) US slice + alpha + mc
df_us = df.loc[df['country']=='United States'].copy()
df_us = df_us.replace([np.inf,-np.inf], np.nan).dropna(subset=['s_j','price']).reset_index(drop=True)

alpha = float(-0.4778)  # IV logit price coefficient (Berry-logit)

# Ensure we have mc/markup in df_us (write from current-ownership markups if missing)
def ownership_matrix(ids):
    return (ids[:,None] == ids[None,:]).astype(float)

def markups_from_omega(dfm, alpha, Omega, ridge=1e-10):
    s = dfm['s_j'].to_numpy(float)
    p = dfm['price'].to_numpy(float)
    J = alpha * (np.diag(s) - np.outer(s, s))              # ∂s/∂p under simple logit
    G = Omega * J
    try:
        m = -npl.solve(G, s)
    except npl.LinAlgError:
        m = -npl.solve(G + ridge*np.eye(len(s)), s)
    mc = p - m
    out = pd.DataFrame({'markup': m, 'mc': mc, 'price': p})
    out['pct_markup'] = np.where(np.isfinite(out['markup']/out['price']),
                                 out['markup']/out['price'], np.nan)
    return out

if 'mc' not in df_us.columns:
    if 'developer' in df_us.columns:
        firm_ids_cur = df_us['developer'].astype('category').cat.codes.to_numpy()
        Omega_current = ownership_matrix(firm_ids_cur)
    else:
        Omega_current = np.eye(len(df_us))
    res_cur = markups_from_omega(df_us, alpha, Omega_current)
    df_us[['mc','markup','pct_markup']] = res_cur[['mc','markup','pct_markup']].reset_index(drop=True)


# 1) Recover baseline δ₀
# One US "market": s0 is outside share
s = df_us['s_j'].to_numpy(float)
s0 = max(1.0 - s.sum(), 1e-12)
delta0 = np.log(np.clip(s, 1e-300, 1)) - np.log(s0)   # δ₀ = ln s_j − ln s0
p0 = df_us['price'].to_numpy(float)
mc = df_us['mc'].to_numpy(float)

# 2) Share and Jacobian at price p
def shares_from_prices(p):
    """Simple logit: δ(p) = δ₀ + α (p - p0); s = exp(δ) / (1 + sum exp(δ))"""
    delta = delta0 + alpha * (p - p0)
    expd = np.exp(np.clip(delta, -700, 700))
    denom = 1.0 + expd.sum()
    return expd / denom

def jacobian_simple_logit(s):
    """∂s/∂p = α [diag(s) − s sᵀ]"""
    return alpha * (np.diag(s) - np.outer(s, s))


# 3) Solve Bertrand FOCs for a given ownership vector
def solve_equilibrium_prices(mc, firm_ids, p_init=None, tol=1e-10, itmax=500, relax=0.6, ridge=1e-10):
    """
    Fixed point on prices:
        m(p) = −(Ω ⊙ J(p))^{-1} s(p),  p = mc + m(p)
    Use damped iterations: p <- (1-relax)*p + relax*(mc + m(p))
    """
    n = len(mc)
    if p_init is None:
        p = p0.copy()
    else:
        p = p_init.copy()
    Omega = ownership_matrix(firm_ids)

    for it in range(itmax):
        s_p = shares_from_prices(p)
        J = jacobian_simple_logit(s_p)
        G = Omega * J
        try:
            m = -npl.solve(G, s_p)
        except npl.LinAlgError:
            m = -npl.solve(G + ridge*np.eye(n), s_p)
        p_new = mc + m
        p_next = (1.0 - relax) * p + relax * p_new
        if np.max(np.abs(p_next - p)) < tol:
            p = p_next
            break
        p = p_next
    else:
        # didn't converge; still return last iterate
        pass
    return p, shares_from_prices(p)


# 4) Baseline stats for Mojang  
if 'developer' not in df_us.columns:
    raise ValueError("Need a 'developer' column to identify Mojang and targets.")

# One categorical mapping for the WHOLE df_us 
dev_cat   = df_us['developer'].astype('category')
dev_codes = dev_cat.cat.codes.to_numpy()
categories = list(dev_cat.cat.categories)

# Helper: get the (unique) code for any developer name from the global dev_codes
def code_for_developer(name: str) -> int:
    codes = np.unique(dev_codes[df_us['developer'] == name])
    if len(codes) == 0:
        raise ValueError(f"Developer not found: {name}")
    return int(codes[0])

# Mojang id from the global dev_codes (not from a re-categorized subset)
moj_mask_any = df_us['developer'].str.contains('Mojang', case=False)
if not moj_mask_any.any():
    raise ValueError("No developer matching 'Mojang' found in US data.")
mojang_id = int(np.unique(dev_codes[moj_mask_any])[0])

# Baseline equilibrium under current ownership
p_eq0, s_eq0 = solve_equilibrium_prices(mc, dev_codes, p_init=p0)
if not np.isfinite(p_eq0).all():
    raise RuntimeError("Baseline price solver did not converge to finite prices.")

moj_mask0 = (dev_codes == mojang_id)
mojang_base_share = float(s_eq0[moj_mask0].sum())
mojang_base_rev   = float((p_eq0[moj_mask0] - 0.0) @ s_eq0[moj_mask0])  # revenue per market-size=1
mojang_base_prof  = float(((p_eq0[moj_mask0] - mc[moj_mask0]) @ s_eq0[moj_mask0]))


# 5) Try each target 
results = []
for target in df_us['developer'].unique():
    if 'mojang' in target.lower():
        continue

    # Use the GLOBAL dev_codes mapping for the target
    target_code = code_for_developer(target)

    # merged ownership: map target's code to Mojang's code
    dev_codes_merged = dev_codes.copy()
    dev_codes_merged[dev_codes == target_code] = mojang_id

    # Solve post-merger equilibrium
    try:
        p_star, s_star = solve_equilibrium_prices(mc, dev_codes_merged, p_init=p_eq0)
        if not (np.isfinite(p_star).all() and np.isfinite(s_star).all()):
            raise RuntimeError("Non-finite solution")
    except Exception as e:
        # If a target fails to converge, skip it but record the failure
        results.append({'target': target, 'Δshare': np.nan, 'Δrevenue': np.nan, 'Δprofit': np.nan})
        continue

    moj_mask = (dev_codes_merged == mojang_id)
    share_new = float(s_star[moj_mask].sum())
    rev_new   = float((p_star[moj_mask] @ s_star[moj_mask]))
    prof_new  = float(((p_star[moj_mask] - mc[moj_mask]) @ s_star[moj_mask]))

    results.append({
        'target': target,
        'Δshare':  share_new - mojang_base_share,
        'Δrevenue': rev_new   - mojang_base_rev,
        'Δprofit':  prof_new  - mojang_base_prof
    })

res = pd.DataFrame(results).sort_values('Δprofit', ascending=False)
print("\n=== Mojang: best acquisition candidates (simple logit, US) ===")
print(res.head(10).to_string(index=False))
# Out:
# === Mojang: best acquisition candidates (simple logit, US) ===
#                                 target   Δshare  Δrevenue  Δprofit
#                         Rockstar Games 0.035134  0.224158 0.107230
#                        Fireproof Games 0.023314  0.045329 0.070134
#                        SQUARE ENIX Ltd 0.022562  0.022206 0.067810
#                             ninja kiwi 0.022305  0.099189 0.067016
#                       Bravestars Games 0.016895  0.016703 0.050429
#                  Ubisoft Entertainment 0.016102  0.027817 0.048018
# Warner Bros. International Enterprises 0.014868  0.035699 0.044272
#                      Clickteam USA LLC 0.013008  0.042771 0.038646
#                   Ironhide Game Studio 0.012641  0.033701 0.037538
#                Coffee Stain Publishing 0.011815  0.065984 0.035053
